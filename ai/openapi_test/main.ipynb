# %%
import requests # API 이용해 자료를 받아오기 위해
import pandas as pd
import xmltodict

# %%
apikey = '6470667174616c6a3737787a725174'

startnum = 1
endnum = 20

url = f"http://openAPI.seoul.go.kr:8088/{apikey}/xml/" \
      f"ListAirQualityByDistrictService/{startnum}/{endnum}"
resp = requests.get(url)          # 실제 호출
print(resp.status_code)           # 200 나오는지 확인
print(resp.headers["Content-Type"])  # application/xml 이어야 정상

# XML → 파이썬 dict 로 변환
data = xmltodict.parse(resp.text)
print(data)       # 구조 확인
# Out:
# 200
# application/xml;charset=UTF-8
# ...

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined

# %%
json = requests.get(url).json()
json
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\smartcity_ai\smartcity-complaint-response\venv\lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
print(response.headers.get("Content-Type"))
# Out:
# application/xml;charset=UTF-8

# %%
print(response.text[:500])                  # 앞부분 500자만 출력
# Out:
# <RESULT><CODE>ERROR-332</CODE><MESSAGE><![CDATA[요청종료위치 값을 확인하십시오.
# 요청인자 중 END_INDEX를 확인하십시오.]]></MESSAGE></RESULT>

# %%
from google import genai

client = genai.Client(api_key="AIzaSyB1hI_WSC94cTzrUy5OWDO74WhbLe7O4UQ")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)

# %%
import requests  # requests 모듈 임포트

def download_file(file_url, save_path):
    with open(save_path, 'wb') as f: # 저장할 파일을 바이너리 쓰기 모드로 열기
        response = requests.get(file_url) # 파일 URL에 GET 요청 보내기
        f.write(response.content) # 응답의 내용을 파일에 쓰기

# URL과 저장 경로 변수를 지정합니다.
url = 'https://apihub.kma.go.kr/api/file?authKey=YOUR_AUTH_KEY'
save_file_path = 'output_file.zip'

# 파일 다운로드 함수를 호출합니다.
download_file(url, save_file_path)

# %% [markdown]
# ### BusID 가져오기

# %%
import requests
import json

# 🔑 필수: 본인의 ODsay API 키 입력
API_KEY = "	Yr3WiBOoOyIeYF3nVaIgfA"

# 🔍 버스 번호와 도시 코드
params = {
    "lang": 0,
    "busNo": "50",
    "CID": 1000,
    "stationListYn": "no",
    "displayCnt": 100,
    "startNO": 1,
    "apiKey": API_KEY
}

url = "https://api.odsay.com/v1/api/searchBusLane"

# 📡 API 요청
response = requests.get(url, params=params)
data = response.json()

# 🚌 busID만 추출
bus_ids = [lane["busID"] for lane in data.get("result", {}).get("lane", [])]

# 💾 JSON 파일로 저장
with open("bus_ids.json", "w", encoding="utf-8") as f:
    json.dump(bus_ids, f, ensure_ascii=False, indent=2)

print("✅ bus_ids.json 파일 저장 완료!")
# Out:
# ✅ bus_ids.json 파일 저장 완료!

# %%
data
# Out:
# {'error': [{'code': '500',
#    'message': '[ApiKeyAuthFailed] ApiKey authentication failed.'}]}

# %%
import requests
import json

# ODsay API 키 입력
API_KEY = "+K/FSRG5T7f+k7k4VXdgJOQJq+bL0D6M7RqPSVozEHk"

url = "https://api.odsay.com/v1/api/searchBusLane"

params = {
    "lang": 0,              # 국문
    "busNo": "50",          # 예시 50까지 있음
    "CID": 1000,            # 서울시 
    "stationListYn": "no",  # 주요 정류장 목록 포함 여부
    "displayCnt": 100,      # 최대 100개 결과
    "startNO": 1,           # 첫번째부터 시작
    "apiKey": API_KEY       # 필수 : API 키
}

response = requests.get(url, params=params)

if response.status_code == 200:
    result = response.json()
    print(json.dumps(result, ensure_ascii=False, indent=2))
else:
    print(" 요청 실패 : ", response.status_code)
# Out:
# {
#   "result": {
#     "totalCityList": {
#       "includeCity": [
#         {
#           "cityName": "서울",
#           "CID": 1000
#         }
#       ]
#     },
#     "totalCount": 8,
#     "lane": [
#       {
#         "busNo": "501",
#         "busID": 1089,
#         "localBusID": "100100077",
#         "type": 11,
#         "busCityName": "서울",
#         "busCityCode": 1000,
#         "busStartPoint": "서울대학교",
#         "busEndPoint": "종로2가",
#         "busFirstTime": "04:30",
#         "busLastTime": "23:30",
#         "busInterval": "7",
#         "bus_Interval_Week": "7",
#         "bus_Interval_Sat": "10",
#         "bus_Interval_Sun": "10",
#         "busCompanyNameKor": "한남여객",
#         "busCompanyID": "73"
#       },
#       {
#         "busNo": "5012",
#         "busID": 1452,
#         "localBusID": "100100248",
#         "type": 12,
#         "busCityName": "서울",
#         "busCityCode": 1000,
#         "busStartPoint": "가산동",
#         "busEndPoint": "용산역",
# ...

# %%
# 🚌 busID만 추출
bus_ids = [lane["busID"] for lane in result.get("result", {}).get("lane", [])]

# 💾 JSON 파일로 저장
with open("bus_ids.json", "w", encoding="utf-8") as f:
    json.dump(bus_ids, f, ensure_ascii=False, indent=2)

print("✅ bus_ids.json 파일 저장 완료!")
# Out:
# ✅ bus_ids.json 파일 저장 완료!

# %%
# Out:
# {'error': [{'code': '500',
#    'message': '[ApiKeyAuthFailed] ApiKey authentication failed.'}]}

# %%
import requests
import json

# ODsay API 키 입력
API_KEY = "+K/FSRG5T7f+k7k4VXdgJOQJq+bL0D6M7RqPSVozEHk"

url = "https://api.odsay.com/v1/api/searchBusLane"

params = {
    "lang": 0,              # 국문
    "busNo": "50",          # 예시 50까지 있음
    "CID": 1000,            # 서울시 
    "stationListYn": "no",  # 주요 정류장 목록 포함 여부
    "displayCnt": 100,      # 최대 100개 결과
    "startNO": 1,           # 첫번째부터 시작
    "apiKey": API_KEY       # 필수 : API 키
}

response = requests.get(url, params=params)

if response.status_code == 200:
    result = response.json()
    print(json.dumps(result, ensure_ascii=False, indent=2))
else:
    print(" 요청 실패 : ", response.status_code)

# %%
import requests
import json
import time

# ODsay API 키 입력
API_KEY = "+K/FSRG5T7f+k7k4VXdgJOQJq+bL0D6M7RqPSVozEHk"

url = "https://api.odsay.com/v1/api/searchBusLane"

# 전체 결과 저장 리스트
all_results = []

# busNo 1~50 반복
for bus_no in range(1, 51):
    params = {
        "lang": 0,              # 국문
        "busNo": "50",          # 예시 50까지 있음
        "CID": 1000,            # 서울시 
        "stationListYn": "no",  # 주요 정류장 목록 포함 여부
        "displayCnt": 100,      # 최대 100개 결과
        "startNO": 1,           # 첫번째부터 시작
        "apiKey": API_KEY       # 필수 : API 키
    }

    print(f" 버스번호 {bus_no} 요청 중...")

    try:
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()

            # 에러 없이 정상 응답이면 저장
            if "result" in data and "lane" in data["result"]:
                all_results.extend(data["result"]["lane"])
                print(f" {bus_no}번 버스 정보 수집 완료")
            else:
                print(f" {bus_no}번 결과 없음 또는 포맷 이상")
        else:
            print(f" 요청 실패 ({bus_no}): {response.status_code}")
    except Exception as e:
        print(f" 예외 발생 ({bus_no}): ", e)
    
    time.sleep(0.2) # 요청 과부하 방지

# JSON 파일 저장
with open("bus_lane_results.json", "w", encoding = "utf-8")as f:
    json.dump(all_results, f, ensure_ascii=False, indent=2)

print("모든 버스 정보 저장 완료")
# Out:
#  버스번호 1 요청 중...
#  1번 버스 정보 수집 완료
#  버스번호 2 요청 중...
#  2번 버스 정보 수집 완료
#  버스번호 3 요청 중...
#  3번 버스 정보 수집 완료
#  버스번호 4 요청 중...
#  4번 버스 정보 수집 완료
#  버스번호 5 요청 중...
#  5번 버스 정보 수집 완료
#  버스번호 6 요청 중...
#  6번 버스 정보 수집 완료
#  버스번호 7 요청 중...
#  7번 버스 정보 수집 완료
#  버스번호 8 요청 중...
#  8번 버스 정보 수집 완료
#  버스번호 9 요청 중...
#  9번 버스 정보 수집 완료
#  버스번호 10 요청 중...
#  10번 버스 정보 수집 완료
#  버스번호 11 요청 중...
#  11번 버스 정보 수집 완료
#  버스번호 12 요청 중...
#  12번 버스 정보 수집 완료
#  버스번호 13 요청 중...
#  13번 버스 정보 수집 완료
#  버스번호 14 요청 중...
#  14번 버스 정보 수집 완료
#  버스번호 15 요청 중...
#  15번 버스 정보 수집 완료
#  버스번호 16 요청 중...
#  16번 버스 정보 수집 완료
#  버스번호 17 요청 중...
#  17번 버스 정보 수집 완료
#  버스번호 18 요청 중...
#  18번 버스 정보 수집 완료
#  버스번호 19 요청 중...
#  19번 버스 정보 수집 완료
#  버스번호 20 요청 중...
#  20번 버스 정보 수집 완료
#  버스번호 21 요청 중...
#  21번 버스 정보 수집 완료
#  버스번호 22 요청 중...
#  22번 버스 정보 수집 완료
#  버스번호 23 요청 중...
#  23번 버스 정보 수집 완료
#  버스번호 24 요청 중...
#  24번 버스 정보 수집 완료
#  버스번호 25 요청 중...
#  25번 버스 정보 수집 완료
#  버스번호 26 요청 중...
#  26번 버스 정보 수집 완료
#  버스번호 27 요청 중...
# ...

# %% [markdown]
# ### Json BusID 전처리

# %%
import json

# 기존 JSON 파일 읽기
with open("bus_lane_results.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# busID만 추출
bus_ids = [item["busID"] for item in data if "busID" in item]

# 새 JSON 파일로 저장
with open("bus_ids.json", "w", encoding="utf-8") as f:
    json.dump(bus_ids, f, ensure_ascii=False, indent=2)

print("busID만 추출 완료")
# Out:
# busID만 추출 완료

# %% [markdown]
# ### 버스노선 상세정보 조회

# %%
import requests
import json
import time

# ODsay 서버 API Key
API_KEY = "+K/FSRG5T7f+k7k4VXdgJOQJq+bL0D6M7RqPSVozEHk"

# bus_ids.json에서 busID 리스트 로드
with open("bus_ids.json", "r", encoding="utf-8") as f:
    bus_ids = json.load(f)

# 요청 URL
url = "https://api.odsay.com/v1/api/busLaneDetail"

# 결과 저장용 리스트
all_results = []

# busID마다 요청
for bus_id in bus_ids:
    params = {
        "apiKey": API_KEY,
        "busID": bus_id,
        "lang": 0,
        "output": "json"
    }

    print(f" busID {bus_id} 조회 중...")

    try:
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()

            if "result" in data:
                all_results.append({
                    "busID": bus_id,
                    "detail": data["result"]
                })
                print(f" busID {bus_id} 수집 완료")
            else:
                print(f" busID {bus_id}: 'result' 키 없음")

        else:
            print(f" 요청 실패 (busID={bus_id}): {response.status_code}")

    except Exception as e:
        print(f" 예외 발생 (busID={bus_id}):", e)

    time.sleep(0.2)  # 과부하 방지

#  JSON 저장
with open("bus_lane_detail_results.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, ensure_ascii=False, indent=2)

print(" 모든 busID 상세 정보 저장 완료 → bus_lane_detail_results.json")
# Out:
#  busID 1089 조회 중...
#  busID 1089 수집 완료
#  busID 1452 조회 중...
#  busID 1452 수집 완료
#  busID 1358 조회 중...
#  busID 1358 수집 완료
#  busID 1092 조회 중...
#  busID 1092 수집 완료
#  busID 1093 조회 중...
#  busID 1093 수집 완료
#  busID 1094 조회 중...
#  busID 1094 수집 완료
#  busID 1405 조회 중...
#  busID 1405 수집 완료
#  busID 1406 조회 중...
#  busID 1406 수집 완료
#  busID 1089 조회 중...
#  busID 1089 수집 완료
#  busID 1452 조회 중...
#  busID 1452 수집 완료
#  busID 1358 조회 중...
#  busID 1358 수집 완료
#  busID 1092 조회 중...
#  busID 1092 수집 완료
#  busID 1093 조회 중...
#  busID 1093 수집 완료
#  busID 1094 조회 중...
#  busID 1094 수집 완료
#  busID 1405 조회 중...
#  busID 1405 수집 완료
#  busID 1406 조회 중...
#  busID 1406 수집 완료
#  busID 1089 조회 중...
#  busID 1089 수집 완료
#  busID 1452 조회 중...
#  busID 1452 수집 완료
#  busID 1358 조회 중...
#  busID 1358 수집 완료
#  busID 1092 조회 중...
#  busID 1092 수집 완료
#  busID 1093 조회 중...
#  busID 1093 수집 완료
#  busID 1094 조회 중...
#  busID 1094 수집 완료
#  busID 1405 조회 중...
#  busID 1405 수집 완료
#  busID 1406 조회 중...
# ...

# %% [markdown]
# ### 공공데이터 API 사용해보기

# %%
import requests
import xmltodict
import json

# 🗝 공공데이터포털에서 발급받은 서비스 키 (인코딩된 상태로 넣기)
SERVICE_KEY = "weN7NRYrnzeBG6m4eo77Aw2B227V7ASF3dS8s5uW17HkctK%2FsIqf6dCqf%2FFLKM1R6gCg2pmQFq%2FcyRfFIr5pXQ%3D%3D"  

# bus_lane_detail_results.json 로드
with open("bus_lane_detail_results.json", "r", encoding="utf-8") as f:
    bus_data = json.load(f)
# 모든 arsID 추출 (중복 제거)
ars_ids = set()
for bus in bus_data:
    stations = bus.get("detail", {}).get("station", [])
    for station in stations:
        if "arsID" in station:
            ars_ids.add(station["arsID"])

url = "http://ws.bus.go.kr/api/rest/stationinfo/getStationByUid"
params = {
    "ServiceKey": SERVICE_KEY,
    "arsId": ars_id
}

response = requests.get(url, params=params)

# 응답은 XML → dict로 변환
if response.status_code == 200:
    parsed = xmltodict.parse(response.text)
    json_data = json.loads(json.dumps(parsed))  # Optional: dict → JSON 형태

    # 도착 정보 출력
    try:
        items = json_data["ServiceResult"]["msgBody"]["itemList"]
        if isinstance(items, list):
            for item in items:
                print(f"🚌 {item['rtNm']} - {item['arrmsg1']}")
        else:
            print(f"🚌 {items['rtNm']} - {items['arrmsg1']}")
    except:
        print("❗ 도착 정보 없음 또는 파싱 오류")
else:
    print("❌ API 호출 실패:", response.status_code)

# %%
import requests
import xmltodict
import json
import time

# 🗝 공공데이터포털에서 발급받은 서비스 키 (인코딩된 상태로 넣기)
SERVICE_KEY = "weN7NRYrnzeBG6m4eo77Aw2B227V7ASF3dS8s5uW17HkctK%2FsIqf6dCqf%2FFLKM1R6gCg2pmQFq%2FcyRfFIr5pXQ%3D%3D"  

# 📥 bus_lane_detail_results.json 로드
with open("bus_lane_detail_results.json", "r", encoding="utf-8") as f:
    bus_data = json.load(f)

# 🔍 모든 arsID 추출 (중복 제거)
ars_ids = set()
for bus in bus_data:
    stations = bus.get("detail", {}).get("station", [])
    for station in stations:
        if "arsID" in station:
            ars_ids.add(station["arsID"])

# 📦 결과 저장 리스트
all_arrival_info = []

# 🔁 arsID마다 반복 요청
for ars_id in ars_ids:
    url = "http://ws.bus.go.kr/api/rest/stationinfo/getStationByUid"
    params = {
        "ServiceKey": SERVICE_KEY,
        "arsId": ars_id
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        try:
            parsed = xmltodict.parse(response.text)
            json_data = json.loads(json.dumps(parsed))

            items = json_data["ServiceResult"]["msgBody"]["itemList"]

            if isinstance(items, list):
                for item in items:
                    all_arrival_info.append(item)
                    print(f"🚌 {ars_id} | {item['rtNm']} - {item['arrmsg1']}")
            else:
                all_arrival_info.append(items)
                print(f"🚌 {ars_id} | {items['rtNm']} - {items['arrmsg1']}")

        except Exception as e:
            print(f"⚠️ arsID {ars_id} 처리 실패:", e)
    else:
        print(f"❌ API 호출 실패: arsID={ars_id}, status={response.status_code}")

    time.sleep(0.2)  # 과부하 방지

# 💾 전체 결과 JSON 저장
with open("arrival_info.json", "w", encoding="utf-8") as f:
    json.dump(all_arrival_info, f, ensure_ascii=False, indent=2)

print("🎉 모든 arsID의 도착 정보 저장 완료 → arrival_info.json")
# Out:
# ⚠️ arsID 18177 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 20167 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 14074 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 20018 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 14182 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 20015 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 03135 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 18193 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 18114 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 22225 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 03124 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 27138 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 14280 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 27135 처리 실패: 'NoneType' object is not subscriptable
# ⚠️ arsID 19827 처리 실패: 'NoneType' object is not subscriptable
# ...

# %%
### test 용
import requests
import xmltodict
import json

# 🔐 공공데이터포털에서 발급받은 서비스 키 (인코딩된 상태로 넣기)
SERVICE_KEY = "weN7NRYrnzeBG6m4eo77Aw2B227V7ASF3dS8s5uW17HkctK%2FsIqf6dCqf%2FFLKM1R6gCg2pmQFq%2FcyRfFIr5pXQ%3D%3D"

# 🧪 테스트용 arsID 하나
ars_id = "21338"  # 예: 한남운수대학동차고지

# API 요청 URL
url = "http://ws.bus.go.kr/api/rest/stationinfo/getStationByUid"
params = {
    "ServiceKey": SERVICE_KEY,
    "arsId": ars_id
}

response = requests.get(url, params=params)

# XML → dict 변환
if response.status_code == 200:
    parsed = xmltodict.parse(response.text)
    json_data = json.loads(json.dumps(parsed))

    service_result = json_data.get("ServiceResult", {})
    msg_body = service_result.get("msgBody")

    if not msg_body or "itemList" not in msg_body:
        print(f"⚠️ arsID {ars_id}: 도착 정보 없음")
    else:
        items = msg_body["itemList"]
        print(f"✅ arsID {ars_id} 도착 정보:")

        if isinstance(items, list):
            for item in items:
                print(f"🚌 {item['rtNm']} - {item['arrmsg1']}")
        else:
            print(f"🚌 {items['rtNm']} - {items['arrmsg1']}")
else:
    print(f"❌ API 호출 실패: {response.status_code}")
# Out:
# ⚠️ arsID 21338: 도착 정보 없음

# %%
import requests
import xmltodict
import json

SERVICE_KEY = "weN7NRYrnzeBG6m4eo77Aw2B227V7ASF3dS8s5uW17HkctK%2FsIqf6dCqf%2FFLKM1R6gCg2pmQFq%2FcyRfFIr5pXQ%3D%3D"
ars_id = "21338"

url = "http://ws.bus.go.kr/api/rest/stationinfo/getStationByUid"
params = {
    "ServiceKey": SERVICE_KEY,
    "arsId": ars_id.strip()
}

response = requests.get(url, params=params)

if response.status_code == 200:
    parsed = xmltodict.parse(response.text)
    json_data = json.loads(json.dumps(parsed))
    
    # 전체 응답 구조 디버깅 출력
    print(json.dumps(json_data, ensure_ascii=False, indent=2))

    # 안전하게 꺼내기
    msg_body = json_data.get("ServiceResult", {}).get("msgBody", {})
    item_list = msg_body.get("itemList")

    if not item_list:
        print(f"⚠️ arsID {ars_id}: 도착 정보 없음 또는 파싱 문제 (itemList 없음)")
    else:
        print(f"✅ arsID {ars_id} 도착 정보:")

        if isinstance(item_list, list):
            for item in item_list:
                print(f"🚌 {item.get('rtNm')} - {item.get('arrmsg1')}")
        elif isinstance(item_list, dict):
            print(f"🚌 {item_list.get('rtNm')} - {item_list.get('arrmsg1')}")
        else:
            print(f"❗ 예상치 못한 itemList 형식: {type(item_list)}")

else:
    print(f"❌ API 호출 실패: {response.status_code}")
# Out:
# {
#   "ServiceResult": {
#     "comMsgHeader": null,
#     "msgHeader": {
#       "headerCd": "7",
#       "headerMsg": "Key인증실패: SERVICE KEY IS NOT REGISTERED ERROR.[인증모듈 에러코드(30)]",
#       "itemCount": "0"
#     },
#     "msgBody": null
#   }
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 25
#      23 # 안전하게 꺼내기
#      24 msg_body = json_data.get("ServiceResult", {}).get("msgBody", {})
# ---> 25 item_list = msg_body.get("itemList")
#      27 if not item_list:
#      28     print(f"⚠️ arsID {ars_id}: 도착 정보 없음 또는 파싱 문제 (itemList 없음)")
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
msg_body = json_data.get("ServiceResult", {}).get("msgBody")

if msg_body is None:
    print(f"❌ arsID {ars_id}: msgBody 없음 → API 키 인증 실패 또는 결과 없음")
    print(json.dumps(json_data, indent=2, ensure_ascii=False))  # 전체 응답 보기
else:
    item_list = msg_body.get("itemList")
    if not item_list:
        print(f"⚠️ arsID {ars_id}: 도착 정보 없음 (itemList 없음)")
    else:
        print(f"✅ arsID {ars_id} 도착 정보:")
        if isinstance(item_list, list):
            for item in item_list:
                print(f"🚌 {item.get('rtNm')} - {item.get('arrmsg1')}")
        elif isinstance(item_list, dict):
            print(f"🚌 {item_list.get('rtNm')} - {item_list.get('arrmsg1')}")
        else:
            print(f"❗ 예상치 못한 itemList 형식: {type(item_list)}")
# Out:
# ❌ arsID 21338: msgBody 없음 → API 키 인증 실패 또는 결과 없음
# {
#   "ServiceResult": {
#     "comMsgHeader": null,
#     "msgHeader": {
#       "headerCd": "7",
#       "headerMsg": "Key인증실패: SERVICE KEY IS NOT REGISTERED ERROR.[인증모듈 에러코드(30)]",
#       "itemCount": "0"
#     },
#     "msgBody": null
#   }
# }

# %%
import requests
import xmltodict
import json

# 🔑 원본 키 (디코딩된 형태로 직접 입력)
SERVICE_KEY = "weN7NRYrnzeBG6m4eo77Aw2B227V7ASF3dS8s5uW17HkctK/sIqf6dCqf/FLKM1R6gCg2pmQFq/cyRfFIr5pXQ=="
ars_id = "21338"

url = "http://ws.bus.go.kr/api/rest/stationinfo/getStationByUid"
params = {
    "ServiceKey": SERVICE_KEY,   # ✅ 디코딩된 원본 사용
    "arsId": ars_id.strip()
}

response = requests.get(url, params=params)

if response.status_code == 200:
    parsed = xmltodict.parse(response.text)
    json_data = json.loads(json.dumps(parsed))
    
    service_result = json_data.get("ServiceResult", {})
    msg_body = service_result.get("msgBody")

    if msg_body is None:
        header_msg = service_result.get("msgHeader", {}).get("headerMsg", "알 수 없는 오류")
        print(f"⚠️ arsID {ars_id}: msgBody 없음 → {header_msg}")
    else:
        item_list = msg_body.get("itemList")
        if not item_list:
            print(f"⚠️ arsID {ars_id}: 도착 정보 없음 (itemList 없음)")
        else:
            print(f"✅ arsID {ars_id} 도착 정보:")
            if isinstance(item_list, list):
                for item in item_list:
                    print(f"🚌 {item.get('rtNm')} - {item.get('arrmsg1')}")
            elif isinstance(item_list, dict):
                print(f"🚌 {item_list.get('rtNm')} - {item_list.get('arrmsg1')}")
            else:
                print(f"❗ 예상치 못한 itemList 형식: {type(item_list)}")

else:
    print(f"❌ API 호출 실패: {response.status_code}")
# Out:
# ✅ arsID 21338 도착 정보:
# 🚌 501 - 출발대기
# 🚌 5517 - 출발대기

# %% [markdown]
# ### bus_lane_detail 전처리

# %%
import json

# 원본 데이터 로드 (예시로 station_data.json이라는 파일에 저장되어 있다고 가정)
with open("bus_lane_detail_results.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# 정류장 리스트 추출
stations = data[0]["detail"]["station"]

# 필요한 정보만 추출
simplified_stations = [
    {
        "stationName": station["stationName"],
        "arsID": station["arsID"]
    }
    for station in stations
]

# 결과 저장
with open("station_list_minimal.json", "w", encoding="utf-8") as f:
    json.dump(simplified_stations, f, ensure_ascii=False, indent=2)

print("✅ 전처리 완료: station_list_minimal.json")
# Out:
# ✅ 전처리 완료: station_list_minimal.json

# %% [markdown]
# ### Subway

# %%
import requests

def get_all_arrivals(statn_nm, apikey, batch_size=100):
    all_data = []
    start = 0

    while True:
        end = start + batch_size - 1
        url = f"http://swopenapi.seoul.go.kr/api/subway/{apikey}/json/realtimeStationArrival/{start}/{end}/{statn_nm}"
        response = requests.get(url)

        if response.status_code != 200:
            print(f"❌ API 호출 실패: {response.status_code}")
            break

        data = response.json()
        rows = data.get("realtimeArrivalList", [])
        all_data.extend(rows)

        # 종료 조건
        if len(rows) < batch_size:
            break
        start += batch_size

    return all_data

# 사용 예시
apikey = "4870596749616c6a373677585a6757"
result = get_all_arrivals("서울", apikey)
print(f"총 {len(result)}건 조회됨")
for row in result:
    print(f"🚇 {row['trainLineNm']} - {row['arvlMsg2']}")
# Out:
# 총 23건 조회됨
# 🚇 검암행 - 공덕방면 - 서울 출발
# 🚇 문산행 - 신촌(경의중앙선)방면 - 서울 도착
# 🚇 인천공항2터미널행 - 공덕방면 (급행) - 서울 출발
# 🚇 동두천행 - 시청방면 - 전역 출발
# 🚇 불암산행 - 회현방면 - 전역 도착
# 🚇 청량리행 - 시청방면 - [20]번째 전역 (성균관대)
# 🚇 광운대행 - 시청방면 - [2]번째 전역 (용산)
# 🚇 동묘앞행 - 시청방면 - 5분 후 (용산)
# 🚇 불암산행 - 회현방면 - 3분 58초 후 (삼각지)
# 🚇 일산행 - 신촌(경의중앙선)방면 - [4]번째 전역 (효창공원앞)
# 🚇 청량리행 - 시청방면 - [32]번째 전역 (평택)
# 🚇 신창행 - 남영방면 (급행) - 서울 진입
# 🚇 서울행 - 서울방면 - 전역 출발
# 🚇 서울행 - 서울방면 (급행) - 전역 출발
# 🚇 신창행 - 남영방면 - 전역 출발
# 🚇 오이도행 - 숙대입구방면 - 전역 도착
# 🚇 덕소행 - 서울방면 - [6]번째 전역 (강매)
# 🚇 서울행 - 서울방면 - 전역 출발
# 🚇 인천행 - 남영방면 - 7분 20초 후 (종로3가)
# 🚇 사당행 - 숙대입구방면 - 7분 후 (동대문역사문화공원)
# 🚇 서동탄행 - 남영방면 - [4]번째 전역 (종로5가)
# 🚇 서울행 - 서울방면 (급행) - [6]번째 전역 (계양)
# 🚇 용문행 - 서울방면 - [13]번째 전역 (일산)

# %%
import requests
import pandas as pd
import time
import json

# ✅ 1. 엑셀에서 지하철 역 이름 불러오기
excel_path = "subway.xlsx"  # 로컬 실행 시 같은 폴더에 둘 것
try:
    df = pd.read_excel(excel_path)
except Exception as e:
    print(f"❌ 엑셀 파일 읽기 실패: {e}")
    exit()

station_names = df["STATN_NM"].dropna().unique().tolist()

# ✅ 2. 서울열린데이터 API 호출 함수
def get_all_arrivals(statn_nm, apikey, batch_size=100):
    all_data = []
    start = 0
    while True:
        end = start + batch_size - 1
        url = f"http://swopenapi.seoul.go.kr/api/subway/{apikey}/json/realtimeStationArrival/{start}/{end}/{statn_nm}"
        try:
            response = requests.get(url, timeout=10)
            if response.status_code != 200:
                print(f"❌ API 호출 실패: {response.status_code} - 역: {statn_nm}")
                break

            data = response.json()
            rows = data.get("realtimeArrivalList", [])
            all_data.extend(rows)

            if len(rows) < batch_size:
                break
            start += batch_size
        except Exception as e:
            print(f"⚠️ [{statn_nm}] 요청 중 오류 발생: {e}")
            break
    return all_data

# ✅ 3. 전체 역에 대해 수집
apikey = "4870596749616c6a373677585a6757"
all_arrival_data = []

for name in station_names:
    print(f"\n🚏 [{name}] 도착 정보 조회 중...")
    result = get_all_arrivals(name, apikey)
    if result:
        for row in result:
            print(f"🚇 {row['trainLineNm']} - {row['arvlMsg2']}")
        all_arrival_data.extend(result)
    else:
        print("❗ 도착 정보 없음 또는 실패")
    time.sleep(0.2)  # 과도한 요청 방지

# ✅ 4. 결과 저장
output_file = "all_subway_arrivals.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(all_arrival_data, f, ensure_ascii=False, indent=2)

print(f"\n✅ 총 {len(all_arrival_data)}건 저장 완료 → {output_file}")
# Out:
# ❌ 엑셀 파일 읽기 실패: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11     print(f"❌ 엑셀 파일 읽기 실패: {e}")
#      12     exit()
# ---> 14 station_names = df["STATN_NM"].dropna().unique().tolist()
#      16 # ✅ 2. 서울열린데이터 API 호출 함수
#      17 def get_all_arrivals(statn_nm, apikey, batch_size=100):
#
# NameError: name 'df' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import requests
import pandas as pd
import time
import json
import os

# ✅ 1. 엑셀에서 지하철 역 이름 불러오기
excel_path = "subway.xlsx"  # 같은 폴더에 둘 것
try:
    df = pd.read_excel(excel_path)
except Exception as e:
    print(f"❌ 엑셀 파일 읽기 실패: {e}")
    exit()

station_names = df["STATN_NM"].dropna().unique().tolist()

# ✅ 2. 서울열린데이터 API 호출 함수
def get_all_arrivals(statn_nm, apikey, batch_size=100):
    all_data = []
    start = 0
    while True:
        end = start + batch_size - 1
        url = f"http://swopenapi.seoul.go.kr/api/subway/{apikey}/json/realtimeStationArrival/{start}/{end}/{statn_nm}"
        try:
            response = requests.get(url, timeout=10)
            if response.status_code != 200:
                print(f"❌ API 호출 실패: {response.status_code} - 역: {statn_nm}")
                break

            data = response.json()
            rows = data.get("realtimeArrivalList", [])
            all_data.extend(rows)

            if len(rows) < batch_size:
                break
            start += batch_size
        except Exception as e:
            print(f"⚠️ [{statn_nm}] 요청 중 오류 발생: {e}")
            break
    return all_data

# ✅ 3. 저장 폴더 생성
output_dir = "subway_arrivals_by_station"
os.makedirs(output_dir, exist_ok=True)

# ✅ 4. 전체 역에 대해 반복 수집 및 저장
apikey = "4870596749616c6a373677585a6757"
total_saved = 0

for name in station_names:
    print(f"\n🚏 [{name}] 도착 정보 조회 중...")
    result = get_all_arrivals(name, apikey)
    if result:
        filename = f"{output_dir}/{name}.json"
        try:
            with open(filename, "w", encoding="utf-8") as f:
                json.dump(result, f, ensure_ascii=False, indent=2)
            print(f"✅ 저장 완료: {filename} ({len(result)}건)")
            total_saved += len(result)
        except Exception as e:
            print(f"❌ 저장 실패: {filename} → {e}")
    else:
        print("❗ 도착 정보 없음 또는 실패")
    time.sleep(0.2)

print(f"\n✅ 전체 저장 완료: 총 {total_saved}건, 파일 수: {len(station_names)}")
# Out:
# ❌ 엑셀 파일 읽기 실패: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12     print(f"❌ 엑셀 파일 읽기 실패: {e}")
#      13     exit()
# ---> 15 station_names = df["STATN_NM"].dropna().unique().tolist()
#      17 # ✅ 2. 서울열린데이터 API 호출 함수
#      18 def get_all_arrivals(statn_nm, apikey, batch_size=100):
#
# NameError: name 'df' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
